# %%
import requests

def availableShips(passengerCount):
    url = "https://swapi-api.alx-tools.com/api/starships/"
    ships = []
    while url:
        response = requests.get(url)
        print(f"Fetching data from: {url}")  # Debug statement
        data = response.json()
        
        for ship in data["results"]:
            print(f"Processing ship: {ship['name']}")  # Debug statement
            
            if (
                ship["passengers"] != "n/a"
                and ship["passengers"] != "unknown"
                and ship["passengers"] != "0"
                and ship["passengers"] != "none"
            ):
                ship["passengers"] = ship["passengers"].replace(",", "")
                if int(ship["passengers"]) >= passengerCount:
                    ships.append(ship["name"])
                    print(f"Ship added: {ship['name']}")  # Debug statement

        url = data["next"]

    print(f"Total ships found: {len(ships)}")  # Debug statement
    return ships

if __name__ == "__main__":
    passenger_count = 10  # Example passenger count
    ships = availableShips(passenger_count)
    print(f"Ships that can hold at least {passenger_count} passengers: {ships}")
# Out:
# Fetching data from: https://swapi-api.alx-tools.com/api/starships/
# Processing ship: CR90 corvette
# Ship added: CR90 corvette
# Processing ship: Star Destroyer
# Processing ship: Sentinel-class landing craft
# Ship added: Sentinel-class landing craft
# Processing ship: Death Star
# Ship added: Death Star
# Processing ship: Millennium Falcon
# Processing ship: Y-wing
# Processing ship: X-wing
# Processing ship: TIE Advanced x1
# Processing ship: Executor
# Ship added: Executor
# Processing ship: Rebel transport
# Ship added: Rebel transport
# Fetching data from: https://swapi-api.alx-tools.com/api/starships/?page=2
# Processing ship: Slave 1
# Processing ship: Imperial shuttle
# Ship added: Imperial shuttle
# Processing ship: EF76 Nebulon-B escort frigate
# Ship added: EF76 Nebulon-B escort frigate
# Processing ship: Calamari Cruiser
# Ship added: Calamari Cruiser
# Processing ship: A-wing
# Processing ship: B-wing
# Processing ship: Republic Cruiser
# Ship added: Republic Cruiser
# Processing ship: Droid control ship
# Ship added: Droid control ship
# Processing ship: Naboo fighter
# Processing ship: Naboo Royal Starship
# Fetching data from: https://swapi-api.alx-tools.com/api/starships/?page=3
# Processing ship: Scimitar
# Processing ship: J-type diplomatic barge
# Ship added: J-type diplomatic barge
# Processing ship: AA-9 Coruscant freighter
# Ship added: AA-9 Coruscant freighter
# Processing ship: Jedi starfighter
# Processing ship: H-type Nubian yacht
# Processing ship: Republic Assault ship
# Ship added: Republic Assault ship
# Processing ship: Solar Sailer
# Ship added: Solar Sailer
# Processing ship: Trade Federation cruiser
# Ship added: Trade Federation cruiser
# Processing ship: Theta-class T-2c shuttle
# Ship added: Theta-class T-2c shuttle
# Processing ship: Republic attack cruiser
# Ship added: Republic attack cruiser
# Fetching data from: https://swapi-api.alx-tools.com/api/starships/?page=4
# Processing ship: Naboo star skiff
# Processing ship: Jedi Interceptor
# Processing ship: arc-170
# Processing ship: Banking clan frigte
# Processing ship: Belbullab-22 starfighter
# Processing ship: V-wing
# Total ships found: 17
# Ships that can hold at least 10 passengers: ['CR90 corvette', 'Sentinel-class landing craft', 'Death Star', 'Executor', 'Rebel transport', 'Imperial shuttle', 'EF76 Nebulon-B escort frigate', 'Calamari Cruiser', 'Republic Cruiser', 'Droid control ship', 'J-type diplomatic barge', 'AA-9 Coruscant freighter', 'Republic Assault ship', 'Solar Sailer', 'Trade Federation cruiser', 'Theta-class T-2c shuttle', 'Republic attack cruiser']
